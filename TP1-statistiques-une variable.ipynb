# %% [markdown]
# # TP : statistique à une variable
#
# Nous allons utiliser dans ce TP le module `matplotlib` qui permet de tracer et visualiser des données ainsi que le module `numpy` pour le traitement.
#
# Objectifs :
# * calculer et interpréter les principaux paramètres de position et dispersion
# * générer une représentation graphique (histogramme, courbe)
# * générer une boîte à moustache

# %% [markdown]
# # Histogramme
#
# Un histogramme sépare les valeurs possibles des données en classes ou groupes.
#
# Pour chaque groupe, on construit un rectangle dont la base correspond aux valeurs de ce groupe et la hauteur correspond à l'effectif dans ce groupe.
#
# Le code ci-dessous génère 3000 données aléatoires suivant une loi normale de moyenne 2000 et d'écart-type 200

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np

data = np.random.normal(2000, 200, 3000)

# %% [markdown]
# Représenter `data`sous forme d'histogramme et mettre les labels 'Salaires' et 'Effectifs' en abscisse et ordonnées. Le titre du graphique sera 'Répartition des salaires'.

# %%
plt.xlabel("Salaires")
plt.ylabel("Effectifs")
plt.hist(data, bins =7)
# Out:
# (array([  34.,  213.,  681., 1052.,  727.,  255.,   38.]),
#  array([1349.41394977, 1531.05044415, 1712.68693853, 1894.32343292,
#         2075.9599273 , 2257.59642168, 2439.23291607, 2620.86941045]),
#  <BarContainer object of 7 artists>)

# %% [markdown]
# Récupérer les bornes de chaque de chaque classe :

# %%
plt.hist(data, bins = 8, color = 'yellow',
            edgecolor = 'red', align = 'mid')
# Out:
# (array([ 21., 137., 449., 810., 905., 489., 162.,  27.]),
#  array([1349.41394977, 1508.34588235, 1667.27781494, 1826.20974752,
#         1985.14168011, 2144.07361269, 2303.00554528, 2461.93747786,
#         2620.86941045]),
#  <BarContainer object of 8 artists>)

# %% [markdown]
# Modifier ces bornes pour choisir [0, 1800, 2000, 2200, 4000] et afficher le nouvel histogramme :

# %%
plt.hist(data, bins = [0, 1800, 2000, 2200, 4000], color = 'yellow',
            edgecolor = 'red', align = 'mid', )
# Out:
# (array([ 514.,  988., 1026.,  472.]),
#  array([   0., 1800., 2000., 2200., 4000.]),
#  <BarContainer object of 4 artists>)

# %% [markdown]
# ## Boîte à moustaches
#
# Appelées _box plot_ ou _whisker plot_ en anglais, elles sont un moyen de représenter le profil d'une série statistique quantitative.
#
# Pour rappel, elles indiquent graphiquement : médiane, quartiles, minimum, maximum.
#
# Une boîte est créee entre le premier et le troisième quartile. Une ligne indique la médiane.
#
# Reprendre les données de salaires et générer une _whisker plot_ :

# %%
fig, axs = plt.subplots(2, 3)
axs[0, 1].boxplot(data, 1)
axs[0, 1].set_title('notched plot')
plt.show()
# Out:
# C:\Users\Guillaume\AppData\Local\Temp\ipykernel_4208\1034777286.py:2: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   axs[0, 1].boxplot(data, 1)

# %% [markdown]
# Calculer le salaire moyen, médian ainsi que l'écart-type :

# %%
# Out:
# (2005.0755946435365, 2008.1776340585552, 197.56618026056861)

# %% [markdown]
# ## Pie Chart de l'Assemblée Nationale
#
# À partir du jeu de données fournis par l'Assemblé nationale, vous allez réaliser un diagramme circulaire de répartition des partis politiques.
#
# Le jeu de données est sur le site opendata de l'Assemblée. Vous le trouverez dans le répertoire sous le nom : `liste_deputes_excel.csv`
#
# On peut l'ouvrir et parcourir les lignes avec le code suivant. On remarque que chaque ligne est un dictionnaire `python` et on remarque surtout le clé `Parti` qui va nous être utile pour la suite.

# %%
import csv

with open('dataset/liste_deputes_excel.csv') as fichiercsv:
    reader = csv.DictReader(fichiercsv)
    for ligne in reader:
        print(ligne)
# Out:
# {'identifiant': '608016', 'Pr�nom': 'V�ronique', 'Nom': 'Louwagie', 'R�gion': 'Normandie', 'D�partement': 'Orne', 'Num�ro de circonscription': '2', 'Profession': 'Expert-comptable', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '719528', 'Pr�nom': 'Jean-Fran�ois', 'Nom': 'Portarrieu', 'R�gion': 'Occitanie', 'D�partement': 'Haute-Garonne', 'Num�ro de circonscription': '5', 'Profession': 'Journaliste', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719540', 'Pr�nom': '�lisabeth', 'Nom': 'Toutut-Picard', 'R�gion': 'Occitanie', 'D�partement': 'Haute-Garonne', 'Num�ro de circonscription': '7', 'Profession': 'Fonctionnaire de cat�gorie A', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '721656', 'Pr�nom': 'C�cile', 'Nom': 'Muschotti', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Var', 'Num�ro de circonscription': '2', 'Profession': 'Directrice d�un centre de formation des apprentis ', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '643103', 'Pr�nom': 'Jean-Jacques', 'Nom': 'Ferrara', 'R�gion': 'Corse', 'D�partement': 'Corse-du-Sud', 'Num�ro de circonscription': '1', 'Profession': 'M�decin', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '719154', 'Pr�nom': 'Didier', 'Nom': 'Martin', 'R�gion': 'Bourgogne-Franche-Comt�', 'D�partement': "C�te-d'Or", 'Num�ro de circonscription': '1', 'Profession': 'Neuroradiologue', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '607619', 'Pr�nom': 'Paul', 'Nom': 'Molac', 'R�gion': 'Bretagne', 'D�partement': 'Morbihan', 'Num�ro de circonscription': '4', 'Profession': 'Professeur du secondaire', 'Groupe politique (complet)': 'Libert�s et Territoires', 'Parti': 'LT'}
# {'identifiant': '719170', 'Pr�nom': 'Fannette', 'Nom': 'Charvier', 'R�gion': 'Bourgogne-Franche-Comt�', 'D�partement': 'Doubs', 'Num�ro de circonscription': '1', 'Profession': 'Employ�e (autres entreprises publiques)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720354', 'Pr�nom': 'Jean-Michel', 'Nom': 'Jacques', 'R�gion': 'Bretagne', 'D�partement': 'Morbihan', 'Num�ro de circonscription': '6', 'Profession': 'Infirmier des forces sp�ciales', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '642935', 'Pr�nom': 'Olivier', 'Nom': 'Becht', 'R�gion': 'Grand Est', 'D�partement': 'Haut-Rhin', 'Num�ro de circonscription': '5', 'Profession': 'Magistrat', 'Groupe politique (complet)': 'Agir ensemble', 'Parti': 'Agir ens'}
# {'identifiant': '2150', 'Pr�nom': 'Jean-Luc', 'Nom': 'M�lenchon', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Bouches-du-Rh�ne', 'Num�ro de circonscription': '4', 'Profession': 'Professeur', 'Groupe politique (complet)': 'La France insoumise', 'Parti': 'FI'}
# {'identifiant': '721336', 'Pr�nom': 'Blandine', 'Nom': 'Brocard', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Rh�ne', 'Num�ro de circonscription': '5', 'Profession': 'Employ�e (secteur priv�)', 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '2796', 'Pr�nom': 'Guy', 'Nom': 'Teissier', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Bouches-du-Rh�ne', 'Num�ro de circonscription': '6', 'Profession': 'Retrait�', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '722194', 'Pr�nom': 'Florence', 'Nom': 'Provendier', 'R�gion': 'Ile-de-France', 'D�partement': 'Hauts-de-Seine', 'Num�ro de circonscription': '10', 'Profession': 'Cadre dirigeant', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719994', 'Pr�nom': 'Catherine', 'Nom': 'Kamowski', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Is�re', 'Num�ro de circonscription': '5', 'Profession': 'Professeur du secondaire et technique', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '718838', 'Pr�nom': 'Fabrice', 'Nom': 'Brun', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Ard�che', 'Num�ro de circonscription': '3', 'Profession': "Industriel-Chef d'entreprise", 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '608695', 'Pr�nom': 'C�cile', 'Nom': 'Untermaier', 'R�gion': 'Bourgogne-Franche-Comt�', 'D�partement': 'Sa�ne-et-Loire', 'Num�ro de circonscription': '4', 'Profession': "Fonctionnaire des grands corps de l'�tat", 'Groupe politique (complet)': 'Socialistes et apparent�s', 'Parti': 'SOC'}
# {'identifiant': '607155', 'Pr�nom': 'Yves', 'Nom': 'Daniel', 'R�gion': 'Pays de la Loire', 'D�partement': 'Loire-Atlantique', 'Num�ro de circonscription': '6', 'Profession': 'Agriculteur-propri�taire retrait�', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '722308', 'Pr�nom': 'Nathalie', 'Nom': 'Serre', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Rh�ne', 'Num�ro de circonscription': '8', 'Profession': 'M�re au foyer', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '720996', 'Pr�nom': "M'jid", 'Nom': 'El Guerrab', 'R�gion': 'Fran�ais �tablis hors de France', 'D�partement': 'Fran�ais �tablis hors de France', 'Num�ro de circonscription': '9', 'Profession': 'Autre cadre (secteur priv�)', 'Groupe politique (complet)': 'Agir ensemble', 'Parti': 'Agir ens'}
# {'identifiant': '604', 'Pr�nom': 'Bernard', 'Nom': 'Bouley', 'R�gion': 'Ile-de-France', 'D�partement': 'Essonne', 'Num�ro de circonscription': '2', 'Profession': "Chef d'entreprise", 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '719484', 'Pr�nom': 'Catherine', 'Nom': 'Dauf�s-Roux', 'R�gion': 'Occitanie', 'D�partement': 'Gard', 'Num�ro de circonscription': '5', 'Profession': "Personnel de direction de l'Education nationale", 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '607090', 'Pr�nom': 'Jean-Pierre', 'Nom': 'Vigier', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Haute-Loire', 'Num�ro de circonscription': '2', 'Profession': 'Fonctionnaire de cat�gorie A', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '720862', 'Pr�nom': 'Fr�d�ric', 'Nom': 'Descrozaille', 'R�gion': 'Ile-de-France', 'D�partement': 'Val-de-Marne', 'Num�ro de circonscription': '1', 'Profession': 'Autre cadre (secteur priv�)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '722038', 'Pr�nom': 'Damien', 'Nom': 'Adam', 'R�gion': 'Normandie', 'D�partement': 'Seine-Maritime', 'Num�ro de circonscription': '1', 'Profession': 'Cadre sup�rieur (secteur priv�)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720644', 'Pr�nom': 'J�r�me', 'Nom': 'Nury', 'R�gion': 'Normandie', 'D�partement': 'Orne', 'Num�ro de circonscription': '3', 'Profession': 'Cadre de la fonction publique', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '334116', 'Pr�nom': 'Jacqueline', 'Nom': 'Maquet', 'R�gion': 'Hauts-de-France', 'D�partement': 'Pas-de-Calais', 'Num�ro de circonscription': '2', 'Profession': 'Directrice de mission', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '717167', 'Pr�nom': 'Mounir', 'Nom': 'Mahjoubi', 'R�gion': 'Ile-de-France', 'D�partement': 'Paris', 'Num�ro de circonscription': '16', 'Profession': 'Autre profession lib�rale', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '331835', 'Pr�nom': 'Monique', 'Nom': 'Iborra', 'R�gion': 'Occitanie', 'D�partement': 'Haute-Garonne', 'Num�ro de circonscription': '6', 'Profession': 'Retrait�e de la Fonction publique', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719286', 'Pr�nom': 'Paul-Andr�', 'Nom': 'Colombani', 'R�gion': 'Corse', 'D�partement': 'Corse-du-Sud', 'Num�ro de circonscription': '2', 'Profession': 'M�decin', 'Groupe politique (complet)': 'Libert�s et Territoires', 'Parti': 'LT'}
# {'identifiant': '721678', 'Pr�nom': 'Robin', 'Nom': 'Reda', 'R�gion': 'Ile-de-France', 'D�partement': 'Essonne', 'Num�ro de circonscription': '7', 'Profession': 'Autres', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '719302', 'Pr�nom': 'Alice', 'Nom': 'Thourot', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Dr�me', 'Num�ro de circonscription': '2', 'Profession': 'Avocat', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '343493', 'Pr�nom': 'Gwendal', 'Nom': 'Rouillard', 'R�gion': 'Bretagne', 'D�partement': 'Morbihan', 'Num�ro de circonscription': '5', 'Profession': 'Cadre du secteur public', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '605963', 'Pr�nom': '�ric', 'Nom': 'Alauzet', 'R�gion': 'Bourgogne-Franche-Comt�', 'D�partement': 'Doubs', 'Num�ro de circonscription': '2', 'Profession': 'M�decin', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720362', 'Pr�nom': 'Belkhir', 'Nom': 'Belhaddad', 'R�gion': 'Grand Est', 'D�partement': 'Moselle', 'Num�ro de circonscription': '1', 'Profession': "Industriel-Chef d'entreprise", 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '718944', 'Pr�nom': 'Cathy', 'Nom': 'Racon-Bouzon', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Bouches-du-Rh�ne', 'Num�ro de circonscription': '5', 'Profession': 'Cadre sup�rieur (secteur priv�)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '721036', 'Pr�nom': 'L�na�ck', 'Nom': 'Adam', 'R�gion': 'Guyane', 'D�partement': 'Guyane', 'Num�ro de circonscription': '2', 'Profession': 'Cadre sup�rieur (entreprises priv�e)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '718954', 'Pr�nom': 'Sa�d', 'Nom': 'Ahamada', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Bouches-du-Rh�ne', 'Num�ro de circonscription': '7', 'Profession': 'Fonctionnaire de cat�gorie A', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '607395', 'Pr�nom': 'St�phane', 'Nom': 'Travert', 'R�gion': 'Normandie', 'D�partement': 'Manche', 'Num�ro de circonscription': '3', 'Profession': 'Cadre commercial', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '267260', 'Pr�nom': 'B�reng�re', 'Nom': 'Poletti', 'R�gion': 'Grand Est', 'D�partement': 'Ardennes', 'Num�ro de circonscription': '1', 'Profession': 'Sage-femme', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '720014', 'Pr�nom': 'Huguette', 'Nom': 'Tiegna', 'R�gion': 'Occitanie', 'D�partement': 'Lot', 'Num�ro de circonscription': '2', 'Profession': 'Docteur, Ing�nieur Recherche et D�velopement', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '722240', 'Pr�nom': 'Pierre', 'Nom': 'Venteau', 'R�gion': 'Nouvelle-Aquitaine', 'D�partement': 'Haute-Vienne', 'Num�ro de circonscription': '2', 'Profession': "Cadre d'organisation professionnelle agricole", 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '2952', 'Pr�nom': 'Jean-Luc', 'Nom': 'Warsmann', 'R�gion': 'Grand Est', 'D�partement': 'Ardennes', 'Num�ro de circonscription': '3', 'Profession': 'Sans profession', 'Groupe politique (complet)': 'UDI et Ind�pendants', 'Parti': 'UDI-I'}
# {'identifiant': '721004', 'Pr�nom': 'Am�lia', 'Nom': 'Lakrafi', 'R�gion': 'Fran�ais �tablis hors de France', 'D�partement': 'Fran�ais �tablis hors de France', 'Num�ro de circonscription': '10', 'Profession': "Chef d'entreprise", 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720672', 'Pr�nom': 'Robert', 'Nom': 'Therry', 'R�gion': 'Hauts-de-France', 'D�partement': 'Pas-de-Calais', 'Num�ro de circonscription': '4', 'Profession': 'Agriculteur retrait�', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '340357', 'Pr�nom': 'Mich�le', 'Nom': 'Victory', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Ard�che', 'Num�ro de circonscription': '2', 'Profession': 'Professeur de lettres-anglais en lyc�e professionnel', 'Groupe politique (complet)': 'Socialistes et apparent�s', 'Parti': 'SOC'}
# {'identifiant': '722046', 'Pr�nom': 'Aurore', 'Nom': 'Berg�', 'R�gion': 'Ile-de-France', 'D�partement': 'Yvelines', 'Num�ro de circonscription': '10', 'Profession': 'Cadre sup�rieur (secteur priv�)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719668', 'Pr�nom': 'Patricia', 'Nom': 'Mirall�s', 'R�gion': 'Occitanie', 'D�partement': 'H�rault', 'Num�ro de circonscription': '1', 'Profession': 'Fonctionnaire de cat�gorie C', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '722062', 'Pr�nom': 'Florence', 'Nom': 'Granjus', 'R�gion': 'Ile-de-France', 'D�partement': 'Yvelines', 'Num�ro de circonscription': '12', 'Profession': 'Cadre sup�rieur (entreprises publiques)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719684', 'Pr�nom': 'Coralie', 'Nom': 'Dubost', 'R�gion': 'Occitanie', 'D�partement': 'H�rault', 'Num�ro de circonscription': '3', 'Profession': 'Conseiller juridique', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720652', 'Pr�nom': 'Bruno', 'Nom': 'Duverg�', 'R�gion': 'Hauts-de-France', 'D�partement': 'Pas-de-Calais', 'Num�ro de circonscription': '1', 'Profession': 'Cadre sup�rieur (secteur priv�)', 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '722280', 'Pr�nom': 'Philippe', 'Nom': 'Meyer', 'R�gion': 'Grand Est', 'D�partement': 'Bas-Rhin', 'Num�ro de circonscription': '6', 'Profession': 'Enseignant', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '719550', 'Pr�nom': 'Liliana', 'Nom': 'Tanguy', 'R�gion': 'Bretagne', 'D�partement': 'Finist�re', 'Num�ro de circonscription': '7', 'Profession': 'Cadre sup�rieur du secteur public ', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719294', 'Pr�nom': 'Mireille', 'Nom': 'Clapot', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Dr�me', 'Num�ro de circonscription': '1', 'Profession': 'Cadre sup�rieur (entreprises publiques)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '1206', 'Pr�nom': 'Nicolas', 'Nom': 'Dupont-Aignan', 'R�gion': 'Ile-de-France', 'D�partement': 'Essonne', 'Num�ro de circonscription': '8', 'Profession': 'Administrateur civil', 'Groupe politique (complet)': 'Non inscrit', 'Parti': 'NI'}
# {'identifiant': '719310', 'Pr�nom': 'C�lia', 'Nom': 'de Lavergne', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Dr�me', 'Num�ro de circonscription': '3', 'Profession': 'Ing�nieur', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '267450', 'Pr�nom': 'R�mi', 'Nom': 'Delatte', 'R�gion': 'Bourgogne-Franche-Comt�', 'D�partement': "C�te-d'Or", 'Num�ro de circonscription': '2', 'Profession': 'Agriculteur', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '720370', 'Pr�nom': 'Ludovic', 'Nom': 'Mendes', 'R�gion': 'Grand Est', 'D�partement': 'Moselle', 'Num�ro de circonscription': '2', 'Profession': 'Cadre sup�rieur (secteur priv�)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719194', 'Pr�nom': 'Yolaine', 'Nom': 'de Courson', 'R�gion': 'Bourgogne-Franche-Comt�', 'D�partement': "C�te-d'Or", 'Num�ro de circonscription': '4', 'Profession': "Chef d'entreprise retrait�e", 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '721352', 'Pr�nom': 'Dani�le', 'Nom': 'Cazarian', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Rh�ne', 'Num�ro de circonscription': '13', 'Profession': 'Administratrice de soci�t�s', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '718962', 'Pr�nom': 'Jean-Marc', 'Nom': 'Zulesi', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Bouches-du-Rh�ne', 'Num�ro de circonscription': '8', 'Profession': 'Autre cadre (secteur priv�)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '643157', 'Pr�nom': 'Philippe', 'Nom': 'Naillet', 'R�gion': 'R�union', 'D�partement': 'R�union', 'Num�ro de circonscription': '1', 'Profession': 'Inspecteur assurance-vie', 'Groupe politique (complet)': 'Socialistes et apparent�s', 'Parti': 'SOC'}
# {'identifiant': '721364', 'Pr�nom': 'Rapha�l', 'Nom': 'Gauvain', 'R�gion': 'Bourgogne-Franche-Comt�', 'D�partement': 'Sa�ne-et-Loire', 'Num�ro de circonscription': '5', 'Profession': 'Avocat', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '718850', 'Pr�nom': 'Pierre', 'Nom': 'Cordier', 'R�gion': 'Grand Est', 'D�partement': 'Ardennes', 'Num�ro de circonscription': '2', 'Profession': 'Fonctionnaire de cat�gorie A', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '767', 'Pr�nom': 'Jacques', 'Nom': 'Cattin', 'R�gion': 'Grand Est', 'D�partement': 'Haut-Rhin', 'Num�ro de circonscription': '2', 'Profession': 'Viticulteur n�gociant', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '720022', 'Pr�nom': 'Michel', 'Nom': 'Lauzzana', 'R�gion': 'Nouvelle-Aquitaine', 'D�partement': 'Lot-et-Garonne', 'Num�ro de circonscription': '1', 'Profession': 'M�decin', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '718860', 'Pr�nom': 'B�n�dicte', 'Nom': 'Taurine', 'R�gion': 'Occitanie', 'D�partement': 'Ari�ge', 'Num�ro de circonscription': '1', 'Profession': 'Professeur du secondaire et technique', 'Groupe politique (complet)': 'La France insoumise', 'Parti': 'FI'}
# {'identifiant': '720038', 'Pr�nom': 'Sandrine', 'Nom': 'Josso', 'R�gion': 'Pays de la Loire', 'D�partement': 'Loire-Atlantique', 'Num�ro de circonscription': '7', 'Profession': 'Autre profession lib�rale', 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '610654', 'Pr�nom': 'Jean-Philippe', 'Nom': 'Nilor', 'R�gion': 'Martinique', 'D�partement': 'Martinique', 'Num�ro de circonscription': '4', 'Profession': 'Collaborateur parlementaire', 'Groupe politique (complet)': 'Gauche d�mocrate et r�publicaine', 'Parti': 'GDR'}
# {'identifiant': '783457', 'Pr�nom': 'Victor', 'Nom': 'Habert-Dassault', 'R�gion': 'Hauts-de-France', 'D�partement': 'Oise', 'Num�ro de circonscription': '1', 'Profession': 'Avocat', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '719676', 'Pr�nom': 'Muriel', 'Nom': 'Ressiguier', 'R�gion': 'Occitanie', 'D�partement': 'H�rault', 'Num�ro de circonscription': '2', 'Profession': 'Employ�e (autres entreprises publiques)', 'Groupe politique (complet)': 'La France insoumise', 'Parti': 'FI'}
# {'identifiant': '722070', 'Pr�nom': 'Pierre', 'Nom': 'Henriet', 'R�gion': 'Pays de la Loire', 'D�partement': 'Vend�e', 'Num�ro de circonscription': '5', 'Profession': 'Professeur du secondaire et technique', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719692', 'Pr�nom': 'Jean-Fran�ois', 'Nom': 'Eliaou', 'R�gion': 'Occitanie', 'D�partement': 'H�rault', 'Num�ro de circonscription': '4', 'Profession': 'M�decin', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719558', 'Pr�nom': 'Erwan', 'Nom': 'Balanant', 'R�gion': 'Bretagne', 'D�partement': 'Finist�re', 'Num�ro de circonscription': '8', 'Profession': 'Photographe et r�alisateur', 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '721690', 'Pr�nom': 'Buon', 'Nom': 'Tan', 'R�gion': 'Ile-de-France', 'D�partement': 'Paris', 'Num�ro de circonscription': '9', 'Profession': "Chef d'entreprise", 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719318', 'Pr�nom': 'Emmanuelle', 'Nom': 'Anthoine', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Dr�me', 'Num�ro de circonscription': '4', 'Profession': 'Avocate', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '755549', 'Pr�nom': 'Sylvain', 'Nom': 'Brial', 'R�gion': 'Wallis-et-Futuna', 'D�partement': 'Wallis-et-Futuna', 'Num�ro de circonscription': '1', 'Profession': "chef d'entreprise", 'Groupe politique (complet)': 'Libert�s et Territoires', 'Parti': 'LT'}
# {'identifiant': '721702', 'Pr�nom': 'Jean-Michel', 'Nom': 'Fauvergue', 'R�gion': 'Ile-de-France', 'D�partement': 'Seine-et-Marne', 'Num�ro de circonscription': '8', 'Profession': 'Haut fonctionnaire dans la Police nationale', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719186', 'Pr�nom': 'Fadila', 'Nom': 'Khattabi', 'R�gion': 'Bourgogne-Franche-Comt�', 'D�partement': "C�te-d'Or", 'Num�ro de circonscription': '3', 'Profession': "Professeur d'anglais CFA                   ", 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720378', 'Pr�nom': 'Richard', 'Nom': 'Lioger', 'R�gion': 'Grand Est', 'D�partement': 'Moselle', 'Num�ro de circonscription': '3', 'Profession': 'Professeur des Universit�s', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719202', 'Pr�nom': 'Didier', 'Nom': 'Paris', 'R�gion': 'Bourgogne-Franche-Comt�', 'D�partement': "C�te-d'Or", 'Num�ro de circonscription': '5', 'Profession': 'Cadre sup�rieur (secteur priv�)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720394', 'Pr�nom': 'Nicole', 'Nom': 'Trisse', 'R�gion': 'Grand Est', 'D�partement': 'Moselle', 'Num�ro de circonscription': '5', 'Profession': 'Salari�e du secteur m�dical', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '608641', 'Pr�nom': 'Yves', 'Nom': 'Blein', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Rh�ne', 'Num�ro de circonscription': '14', 'Profession': 'Cadre sup�rieur du secteur priv�', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '1029', 'Pr�nom': 'Bernard', 'Nom': 'Deflesselles', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Bouches-du-Rh�ne', 'Num�ro de circonscription': '9', 'Profession': 'Ing�nieur', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '721372', 'Pr�nom': 'Damien', 'Nom': 'Pichereau', 'R�gion': 'Pays de la Loire', 'D�partement': 'Sarthe', 'Num�ro de circonscription': '1', 'Profession': 'Employ� (secteur priv�)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '718978', 'Pr�nom': 'Mohamed', 'Nom': 'Laqhila', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Bouches-du-Rh�ne', 'Num�ro de circonscription': '11', 'Profession': 'Expert-Comptable-Commissaire aux Comptes', 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '722082', 'Pr�nom': 'Fran�oise', 'Nom': 'Ballet-Blu', 'R�gion': 'Nouvelle-Aquitaine', 'D�partement': 'Vienne', 'Num�ro de circonscription': '1', 'Profession': "Chef d'entreprise", 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720030', 'Pr�nom': 'Alexandre', 'Nom': 'Freschi', 'R�gion': 'Nouvelle-Aquitaine', 'D�partement': 'Lot-et-Garonne', 'Num�ro de circonscription': '2', 'Profession': 'Dirigeant de soci�t�', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '718868', 'Pr�nom': 'Michel', 'Nom': 'Larive', 'R�gion': 'Occitanie', 'D�partement': 'Ari�ge', 'Num�ro de circonscription': '2', 'Profession': "Profession rattach�e � l'enseignement", 'Groupe politique (complet)': 'La France insoumise', 'Parti': 'FI'}
# {'identifiant': '720046', 'Pr�nom': 'Audrey', 'Nom': 'Dufeu', 'R�gion': 'Pays de la Loire', 'D�partement': 'Loire-Atlantique', 'Num�ro de circonscription': '8', 'Profession': 'Directrice �tablissement de sant�', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '721024', 'Pr�nom': 'Anne', 'Nom': 'Genetet', 'R�gion': 'Fran�ais �tablis hors de France', 'D�partement': 'Fran�ais �tablis hors de France', 'Num�ro de circonscription': '11', 'Profession': 'M�decin', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '722202', 'Pr�nom': 'S�bastien', 'Nom': 'Jumel', 'R�gion': 'Normandie', 'D�partement': 'Seine-Maritime', 'Num�ro de circonscription': '6', 'Profession': 'Permanent politique', 'Groupe politique (complet)': 'Gauche d�mocrate et r�publicaine', 'Parti': 'GDR'}
# {'identifiant': '783463', 'Pr�nom': 'Sophie', 'Nom': 'M�tadier', 'R�gion': 'Centre-Val de Loire', 'D�partement': 'Indre-et-Loire', 'Num�ro de circonscription': '3', 'Profession': 'Urbaniste', 'Groupe politique (complet)': 'UDI et Ind�pendants', 'Parti': 'UDI-I'}
# {'identifiant': '642764', 'Pr�nom': 'Jo�l', 'Nom': 'Aviragnet', 'R�gion': 'Occitanie', 'D�partement': 'Haute-Garonne', 'Num�ro de circonscription': '8', 'Profession': "Directeur d'un �tablissement pour l'enfance handicap�e", 'Groupe politique (complet)': 'Socialistes et apparent�s', 'Parti': 'SOC'}
# {'identifiant': '719700', 'Pr�nom': 'Philippe', 'Nom': 'Hupp�', 'R�gion': 'Occitanie', 'D�partement': 'H�rault', 'Num�ro de circonscription': '5', 'Profession': 'Homme de lettres et artiste', 'Groupe politique (complet)': 'Agir ensemble', 'Parti': 'Agir ens'}
# {'identifiant': '722094', 'Pr�nom': 'Christine', 'Nom': 'Hennion', 'R�gion': 'Ile-de-France', 'D�partement': 'Hauts-de-Seine', 'Num�ro de circonscription': '3', 'Profession': 'Cadre sup�rieur (secteur priv�)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '2449', 'Pr�nom': 'Jean-Pierre', 'Nom': 'Pont', 'R�gion': 'Hauts-de-France', 'D�partement': 'Pas-de-Calais', 'Num�ro de circonscription': '5', 'Profession': 'M�decin', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720516', 'Pr�nom': 'Florence', 'Nom': 'Morlighem', 'R�gion': 'Hauts-de-France', 'D�partement': 'Nord', 'Num�ro de circonscription': '11', 'Profession': 'Gestionnaire de copropri�t�', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720684', 'Pr�nom': 'Pierre-Henri', 'Nom': 'Dumont', 'R�gion': 'Hauts-de-France', 'D�partement': 'Pas-de-Calais', 'Num�ro de circonscription': '7', 'Profession': 'Collaborateur parlementaire', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '606202', 'Pr�nom': 'Fran�oise', 'Nom': 'Dumas', 'R�gion': 'Occitanie', 'D�partement': 'Gard', 'Num�ro de circonscription': '1', 'Profession': 'Cadre sup�rieur de la fonction publique, directeur territorial', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '643205', 'Pr�nom': 'Anne-Christine', 'Nom': 'Lang', 'R�gion': 'Ile-de-France', 'D�partement': 'Paris', 'Num�ro de circonscription': '10', 'Profession': 'Cadre territorial', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '721710', 'Pr�nom': 'Mich�le', 'Nom': 'Peyron', 'R�gion': 'Ile-de-France', 'D�partement': 'Seine-et-Marne', 'Num�ro de circonscription': '9', 'Profession': 'Autre cadre (secteur priv�)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719338', 'Pr�nom': 'Graziella', 'Nom': 'Melchior', 'R�gion': 'Bretagne', 'D�partement': 'Finist�re', 'Num�ro de circonscription': '5', 'Profession': 'Professeure agr�g�e du sup�rieur', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '721666', 'Pr�nom': 'Edith', 'Nom': 'Audibert', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Var', 'Num�ro de circonscription': '3', 'Profession': 'Retrait�e', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '720386', 'Pr�nom': 'Fabien', 'Nom': 'Di Filippo', 'R�gion': 'Grand Est', 'D�partement': 'Moselle', 'Num�ro de circonscription': '4', 'Profession': 'Cadre du secteur priv�', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '719210', 'Pr�nom': 'Bruno', 'Nom': 'Joncour', 'R�gion': 'Bretagne', 'D�partement': "C�tes-d'Armor", 'Num�ro de circonscription': '1', 'Profession': 'Secr�taire administratif des affaires sanitaires et sociales', 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '720402', 'Pr�nom': 'Xavier', 'Nom': 'Paluszkiewicz', 'R�gion': 'Grand Est', 'D�partement': 'Meurthe-et-Moselle', 'Num�ro de circonscription': '3', 'Profession': 'Employ� (secteur priv�)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '605518', 'Pr�nom': 'Fran�ois-Michel', 'Nom': 'Lambert', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Bouches-du-Rh�ne', 'Num�ro de circonscription': '10', 'Profession': 'Profession lib�rale', 'Groupe politique (complet)': 'Libert�s et Territoires', 'Parti': 'LT'}
# {'identifiant': '335054', 'Pr�nom': 'Marietta', 'Nom': 'Karamanli', 'R�gion': 'Pays de la Loire', 'D�partement': 'Sarthe', 'Num�ro de circonscription': '2', 'Profession': "Professeur dans l'enseignement sup�rieur", 'Groupe politique (complet)': 'Socialistes et apparent�s', 'Parti': 'SOC'}
# {'identifiant': '267440', 'Pr�nom': '�ric', 'Nom': 'Diard', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Bouches-du-Rh�ne', 'Num�ro de circonscription': '12', 'Profession': 'Avocat', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '718876', 'Pr�nom': 'Gr�gory', 'Nom': 'Besson-Moreau', 'R�gion': 'Grand Est', 'D�partement': 'Aube', 'Num�ro de circonscription': '1', 'Profession': 'Pr�sident de soci�t�', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720054', 'Pr�nom': 'Yannick', 'Nom': 'Haury', 'R�gion': 'Pays de la Loire', 'D�partement': 'Loire-Atlantique', 'Num�ro de circonscription': '9', 'Profession': 'Pharmacien', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '2155', 'Pr�nom': 'G�rard', 'Nom': 'Menuel', 'R�gion': 'Grand Est', 'D�partement': 'Aube', 'Num�ro de circonscription': '3', 'Profession': 'Agriculteur', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '267780', 'Pr�nom': 'Agn�s', 'Nom': 'Firmin Le Bodo', 'R�gion': 'Normandie', 'D�partement': 'Seine-Maritime', 'Num�ro de circonscription': '7', 'Profession': 'Pharmacien', 'Groupe politique (complet)': 'Agir ensemble', 'Parti': 'Agir ens'}
# {'identifiant': '508', 'Pr�nom': 'Gis�le', 'Nom': 'Bi�mouret', 'R�gion': 'Occitanie', 'D�partement': 'Gers', 'Num�ro de circonscription': '2', 'Profession': 'Assistante parlementaire', 'Groupe politique (complet)': 'Socialistes et apparent�s', 'Parti': 'SOC'}
# {'identifiant': '722102', 'Pr�nom': 'Annie', 'Nom': 'Vidal', 'R�gion': 'Normandie', 'D�partement': 'Seine-Maritime', 'Num�ro de circonscription': '2', 'Profession': 'Charg�e de projet', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719718', 'Pr�nom': 'Laurence', 'Nom': 'Maillart-M�haignerie', 'R�gion': 'Bretagne', 'D�partement': 'Ille-et-Vilaine', 'Num�ro de circonscription': '2', 'Profession': 'Chef entreprise', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720692', 'Pr�nom': 'Fabien', 'Nom': 'Roussel', 'R�gion': 'Hauts-de-France', 'D�partement': 'Nord', 'Num�ro de circonscription': '20', 'Profession': 'Attach� parlementaire', 'Groupe politique (complet)': 'Gauche d�mocrate et r�publicaine', 'Parti': 'GDR'}
# {'identifiant': '721844', 'Pr�nom': 'B�atrice', 'Nom': 'Piron', 'R�gion': 'Ile-de-France', 'D�partement': 'Yvelines', 'Num�ro de circonscription': '3', 'Profession': "Chef d'entreprise", 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719330', 'Pr�nom': 'Fabien', 'Nom': 'Gouttefarde', 'R�gion': 'Normandie', 'D�partement': 'Eure', 'Num�ro de circonscription': '2', 'Profession': 'Fonctionnaire de cat�gorie A', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '721718', 'Pr�nom': 'St�phanie', 'Nom': 'Do', 'R�gion': 'Ile-de-France', 'D�partement': 'Seine-et-Marne', 'Num�ro de circonscription': '10', 'Profession': 'Fonctionnaire de cat�gorie A', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '606171', 'Pr�nom': 'Richard', 'Nom': 'Ferrand', 'R�gion': 'Bretagne', 'D�partement': 'Finist�re', 'Num�ro de circonscription': '6', 'Profession': 'Cadre du secteur priv�', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720802', 'Pr�nom': 'Catherine', 'Nom': 'Pujol', 'R�gion': 'Occitanie', 'D�partement': 'Pyr�n�es-Orientales', 'Num�ro de circonscription': '2', 'Profession': 'non communiqu�', 'Groupe politique (complet)': 'Non inscrit', 'Parti': 'NI'}
# {'identifiant': '719218', 'Pr�nom': 'Herv�', 'Nom': 'Berville', 'R�gion': 'Bretagne', 'D�partement': "C�tes-d'Armor", 'Num�ro de circonscription': '2', 'Profession': 'Autre cadre (secteur priv�)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '642847', 'Pr�nom': 'Thibault', 'Nom': 'Bazin', 'R�gion': 'Grand Est', 'D�partement': 'Meurthe-et-Moselle', 'Num�ro de circonscription': '4', 'Profession': 'Autre cadre (secteur priv�)', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '721384', 'Pr�nom': 'Pascale', 'Nom': 'Fontenel-Personne', 'R�gion': 'Pays de la Loire', 'D�partement': 'Sarthe', 'Num�ro de circonscription': '3', 'Profession': "Industriel-Chef d'entreprise", 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '718990', 'Pr�nom': 'Anne', 'Nom': 'Blanc', 'R�gion': 'Occitanie', 'D�partement': 'Aveyron', 'Num�ro de circonscription': '2', 'Profession': "Infirmi�re dipl�m�e d'Etat", 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '267318', 'Pr�nom': 'Jean-Carles', 'Nom': 'Grelier', 'R�gion': 'Pays de la Loire', 'D�partement': 'Sarthe', 'Num�ro de circonscription': '5', 'Profession': 'Avocat', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '718884', 'Pr�nom': 'Val�rie', 'Nom': 'Bazin-Malgras', 'R�gion': 'Grand Est', 'D�partement': 'Aube', 'Num�ro de circonscription': '2', 'Profession': 'Commer�ante', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '607193', 'Pr�nom': 'Sophie', 'Nom': 'Errante', 'R�gion': 'Pays de la Loire', 'D�partement': 'Loire-Atlantique', 'Num�ro de circonscription': '10', 'Profession': "Industriel-Chef d'entreprise", 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '330240', 'Pr�nom': '�ric', 'Nom': 'Ciotti', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Alpes-Maritimes', 'Num�ro de circonscription': '1', 'Profession': 'Autre profession', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '720074', 'Pr�nom': 'Caroline', 'Nom': 'Janvier', 'R�gion': 'Centre-Val de Loire', 'D�partement': 'Loiret', 'Num�ro de circonscription': '2', 'Profession': 'Autre cadre (secteur priv�)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '330008', 'Pr�nom': 'Xavier', 'Nom': 'Breton', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Ain', 'Num�ro de circonscription': '1', 'Profession': 'Cadre territorial', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '774958', 'Pr�nom': 'G�rard', 'Nom': 'Leseul', 'R�gion': 'Normandie', 'D�partement': 'Seine-Maritime', 'Num�ro de circonscription': '5', 'Profession': "Cadre d'entreprise / enseignant universitaire", 'Groupe politique (complet)': 'Socialistes et apparent�s', 'Parti': 'SOC'}
# {'identifiant': '335612', 'Pr�nom': 'Jean-Paul', 'Nom': 'Lecoq', 'R�gion': 'Normandie', 'D�partement': 'Seine-Maritime', 'Num�ro de circonscription': '8', 'Profession': 'Fonctionnaire de cat�gorie B', 'Groupe politique (complet)': 'Gauche d�mocrate et r�publicaine', 'Parti': 'GDR'}
# {'identifiant': '718674', 'Pr�nom': 'Olga', 'Nom': 'Givernet', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Ain', 'Num�ro de circonscription': '3', 'Profession': 'Ing�nieure a�ronautique', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '346054', 'Pr�nom': 'Emmanuel', 'Nom': 'Maquet', 'R�gion': 'Hauts-de-France', 'D�partement': 'Somme', 'Num�ro de circonscription': '3', 'Profession': "Agent g�n�ral d'assurances", 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '719710', 'Pr�nom': 'Dominique', 'Nom': 'David', 'R�gion': 'Nouvelle-Aquitaine', 'D�partement': 'Gironde', 'Num�ro de circonscription': '1', 'Profession': 'Cadre sup�rieur (secteur priv�)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '722110', 'Pr�nom': 'Hubert', 'Nom': 'Wulfranc', 'R�gion': 'Normandie', 'D�partement': 'Seine-Maritime', 'Num�ro de circonscription': '3', 'Profession': "Profession rattach�e � l'enseignement", 'Groupe politique (complet)': 'Gauche d�mocrate et r�publicaine', 'Parti': 'GDR'}
# {'identifiant': '720696', 'Pr�nom': 'B�atrice', 'Nom': 'Descamps', 'R�gion': 'Hauts-de-France', 'D�partement': 'Nord', 'Num�ro de circonscription': '21', 'Profession': 'Enseignant 1er deg.-directeur �cole', 'Groupe politique (complet)': 'UDI et Ind�pendants', 'Parti': 'UDI-I'}
# {'identifiant': '721852', 'Pr�nom': 'Marie', 'Nom': 'Lebec', 'R�gion': 'Ile-de-France', 'D�partement': 'Yvelines', 'Num�ro de circonscription': '4', 'Profession': 'Consultante en affaires publiques', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '721726', 'Pr�nom': 'Sereine', 'Nom': 'Mauborgne', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Var', 'Num�ro de circonscription': '4', 'Profession': 'Infirmi�re lib�rale', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719350', 'Pr�nom': 'Marie', 'Nom': 'Tamarelle-Verhaeghe', 'R�gion': 'Normandie', 'D�partement': 'Eure', 'Num�ro de circonscription': '3', 'Profession': 'M�decin', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '721742', 'Pr�nom': 'Isabelle', 'Nom': 'Florennes', 'R�gion': 'Ile-de-France', 'D�partement': 'Hauts-de-Seine', 'Num�ro de circonscription': '4', 'Profession': 'Fonctionnaire de cat�gorie A', 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '1874', 'Pr�nom': 'Marc', 'Nom': 'Le Fur', 'R�gion': 'Bretagne', 'D�partement': "C�tes-d'Armor", 'Num�ro de circonscription': '3', 'Profession': 'Sous-pr�fet', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '607553', 'Pr�nom': 'Dominique', 'Nom': 'Potier', 'R�gion': 'Grand Est', 'D�partement': 'Meurthe-et-Moselle', 'Num�ro de circonscription': '5', 'Profession': 'Agriculteur', 'Groupe politique (complet)': 'Socialistes et apparent�s', 'Parti': 'SOC'}
# {'identifiant': '720422', 'Pr�nom': 'Adrien', 'Nom': 'Quatennens', 'R�gion': 'Hauts-de-France', 'D�partement': 'Nord', 'Num�ro de circonscription': '1', 'Profession': 'Employ� (secteur priv�)', 'Groupe politique (complet)': 'La France insoumise', 'Parti': 'FI'}
# {'identifiant': '721398', 'Pr�nom': 'Typhanie', 'Nom': 'Degois', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Savoie', 'Num�ro de circonscription': '1', 'Profession': 'Juriste', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719006', 'Pr�nom': 'Fabrice', 'Nom': 'Le Vigoureux', 'R�gion': 'Normandie', 'D�partement': 'Calvados', 'Num�ro de circonscription': '1', 'Profession': 'Professeur des Universit�s', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '722090', 'Pr�nom': 'B�n�dicte', 'Nom': 'P�telle', 'R�gion': 'Ile-de-France', 'D�partement': 'Hauts-de-Seine', 'Num�ro de circonscription': '2', 'Profession': 'Professeur des �coles (sp�cialit� fran�ais langue �trang�re)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720066', 'Pr�nom': 'St�phanie', 'Nom': 'Rist', 'R�gion': 'Centre-Val de Loire', 'D�partement': 'Loiret', 'Num�ro de circonscription': '1', 'Profession': 'M�decin', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '774956', 'Pr�nom': 'Yves', 'Nom': 'Hemedinger', 'R�gion': 'Grand Est', 'D�partement': 'Haut-Rhin', 'Num�ro de circonscription': '1', 'Profession': 'Cadre du secteur priv�', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '718894', 'Pr�nom': 'Lo�c', 'Nom': 'Dombreval', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Alpes-Maritimes', 'Num�ro de circonscription': '2', 'Profession': "Chef d'entreprise", 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '267735', 'Pr�nom': 'Claude', 'Nom': 'de Ganay', 'R�gion': 'Centre-Val de Loire', 'D�partement': 'Loiret', 'Num�ro de circonscription': '3', 'Profession': '', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '342196', 'Pr�nom': 'Claudia', 'Nom': 'Rouaux', 'R�gion': 'Bretagne', 'D�partement': 'Ille-et-Vilaine', 'Num�ro de circonscription': '3', 'Profession': "Gestionnaire � l'INRAE", 'Groupe politique (complet)': 'Socialistes et apparent�s', 'Parti': 'SOC'}
# {'identifiant': '1012', 'Pr�nom': 'Charles', 'Nom': 'de la Verpilli�re', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Ain', 'Num�ro de circonscription': '2', 'Profession': "Conseiller d'�tat", 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '774952', 'Pr�nom': 'Philippe', 'Nom': 'Benassaya', 'R�gion': 'Ile-de-France', 'D�partement': 'Yvelines', 'Num�ro de circonscription': '11', 'Profession': 'Conseiller en communication', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '721046', 'Pr�nom': 'Nathalie', 'Nom': 'Bassire', 'R�gion': 'R�union', 'D�partement': 'R�union', 'Num�ro de circonscription': '3', 'Profession': "Retrait�e de l'enseignement", 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '718682', 'Pr�nom': 'St�phane', 'Nom': 'Trompille', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Ain', 'Num�ro de circonscription': '4', 'Profession': 'Employ� de banque', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '722228', 'Pr�nom': 'Jean-Claude', 'Nom': 'Leclabart', 'R�gion': 'Hauts-de-France', 'D�partement': 'Somme', 'Num�ro de circonscription': '4', 'Profession': 'Retrait� agricole', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '722118', 'Pr�nom': 'Sira', 'Nom': 'Sylla', 'R�gion': 'Normandie', 'D�partement': 'Seine-Maritime', 'Num�ro de circonscription': '4', 'Profession': 'Avocate', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719728', 'Pr�nom': 'Ga�l', 'Nom': 'Le Bohec', 'R�gion': 'Bretagne', 'D�partement': 'Ille-et-Vilaine', 'Num�ro de circonscription': '4', 'Profession': 'Entrepreneur', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '335999', 'Pr�nom': 'Delphine', 'Nom': 'Batho', 'R�gion': 'Nouvelle-Aquitaine', 'D�partement': 'Deux-S�vres', 'Num�ro de circonscription': '2', 'Profession': 'Cadre territorial', 'Groupe politique (complet)': 'Non inscrit', 'Parti': 'NI'}
# {'identifiant': '720704', 'Pr�nom': 'Laurence', 'Nom': 'Vichnievsky', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Puy-de-D�me', 'Num�ro de circonscription': '3', 'Profession': 'Magistrat', 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '721734', 'Pr�nom': 'Philippe', 'Nom': 'Michel-Kleisbauer', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Var', 'Num�ro de circonscription': '5', 'Profession': 'Conseiller juridique', 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '643127', 'Pr�nom': 'Bruno', 'Nom': 'Questel', 'R�gion': 'Normandie', 'D�partement': 'Eure', 'Num�ro de circonscription': '4', 'Profession': 'Avocat', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719002', 'Pr�nom': 'Julien', 'Nom': 'Ravier', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Bouches-du-Rh�ne', 'Num�ro de circonscription': '1', 'Profession': 'Directeur des relations institutionnelles et m�dias', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '721750', 'Pr�nom': 'C�line', 'Nom': 'Calvez', 'R�gion': 'Ile-de-France', 'D�partement': 'Hauts-de-Seine', 'Num�ro de circonscription': '5', 'Profession': 'Consultante communication', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719372', 'Pr�nom': 'Guillaume', 'Nom': 'Kasbarian', 'R�gion': 'Centre-Val de Loire', 'D�partement': 'Eure-et-Loir', 'Num�ro de circonscription': '1', 'Profession': 'Cadre sup�rieur (secteur priv�)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719660', 'Pr�nom': 'Christelle', 'Nom': 'Dubos', 'R�gion': 'Nouvelle-Aquitaine', 'D�partement': 'Gironde', 'Num�ro de circonscription': '12', 'Profession': "Directrice d'un service emploi et solidarit�s", 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '721522', 'Pr�nom': 'Xavier', 'Nom': 'Batut', 'R�gion': 'Normandie', 'D�partement': 'Seine-Maritime', 'Num�ro de circonscription': '10', 'Profession': 'Autre cadre (secteur priv�)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '721832', 'Pr�nom': 'Sandra', 'Nom': 'Bo�lle', 'R�gion': 'Ile-de-France', 'D�partement': 'Paris', 'Num�ro de circonscription': '14', 'Profession': '', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '720414', 'Pr�nom': 'Patrice', 'Nom': 'Perrot', 'R�gion': 'Bourgogne-Franche-Comt�', 'D�partement': 'Ni�vre', 'Num�ro de circonscription': '2', 'Profession': "Industriel-Chef d'entreprise", 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720430', 'Pr�nom': 'Ugo', 'Nom': 'Bernalicis', 'R�gion': 'Hauts-de-France', 'D�partement': 'Nord', 'Num�ro de circonscription': '2', 'Profession': 'Fonctionnaire de cat�gorie A', 'Groupe politique (complet)': 'La France insoumise', 'Parti': 'FI'}
# {'identifiant': '266808', 'Pr�nom': 'Vincent', 'Nom': 'Rolland', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Savoie', 'Num�ro de circonscription': '2', 'Profession': 'Collaborateur parlementaire', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '1198', 'Pr�nom': 'Laurence', 'Nom': 'Dumont', 'R�gion': 'Normandie', 'D�partement': 'Calvados', 'Num�ro de circonscription': '2', 'Profession': "Charg�e d'�tudes", 'Groupe politique (complet)': 'Socialistes et apparent�s', 'Parti': 'SOC'}
# ...
# {'identifiant': '267337', 'Pr�nom': 'Claire', 'Nom': 'Bouchet', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Hautes-Alpes', 'Num�ro de circonscription': '2', 'Profession': 'Employ�e de la fonction publique retrait�e', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720614', 'Pr�nom': 'Marine', 'Nom': 'Le Pen', 'R�gion': 'Hauts-de-France', 'D�partement': 'Pas-de-Calais', 'Num�ro de circonscription': '11', 'Profession': 'Avocate', 'Groupe politique (complet)': 'Non inscrit', 'Parti': 'NI'}
# {'identifiant': '267289', 'Pr�nom': 'Jean-Pierre', 'Nom': 'Door', 'R�gion': 'Centre-Val de Loire', 'D�partement': 'Loiret', 'Num�ro de circonscription': '4', 'Profession': 'Cardiologue', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '720630', 'Pr�nom': 'Maxime', 'Nom': 'Minot', 'R�gion': 'Hauts-de-France', 'D�partement': 'Oise', 'Num�ro de circonscription': '7', 'Profession': 'Employ� (secteur priv�)', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '719496', 'Pr�nom': 'Pierre', 'Nom': 'Cabar�', 'R�gion': 'Occitanie', 'D�partement': 'Haute-Garonne', 'Num�ro de circonscription': '1', 'Profession': 'Artisan', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719512', 'Pr�nom': 'Corinne', 'Nom': 'Vignon', 'R�gion': 'Occitanie', 'D�partement': 'Haute-Garonne', 'Num�ro de circonscription': '3', 'Profession': 'Cadre sup�rieur (secteur priv�)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719250', 'Pr�nom': 'Philippe', 'Nom': 'Chassaing', 'R�gion': 'Nouvelle-Aquitaine', 'D�partement': 'Dordogne', 'Num�ro de circonscription': '1', 'Profession': 'Professeur du secondaire ', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '721644', 'Pr�nom': 'Rodrigue', 'Nom': 'Kokouendo', 'R�gion': 'Ile-de-France', 'D�partement': 'Seine-et-Marne', 'Num�ro de circonscription': '7', 'Profession': 'Autre cadre (secteur priv�)', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719266', 'Pr�nom': 'Jean-Pierre', 'Nom': 'Cubertafon', 'R�gion': 'Nouvelle-Aquitaine', 'D�partement': 'Dordogne', 'Num�ro de circonscription': '3', 'Profession': 'Retrait� des professions lib�rales', 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '760658', 'Pr�nom': 'Francis', 'Nom': 'Chouat', 'R�gion': 'Ile-de-France', 'D�partement': 'Essonne', 'Num�ro de circonscription': '1', 'Profession': 'Retrait�', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720318', 'Pr�nom': 'H�l�ne', 'Nom': 'Zannier', 'R�gion': 'Grand Est', 'D�partement': 'Moselle', 'Num�ro de circonscription': '7', 'Profession': 'Fonctionnaire de cat�gorie A', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719138', 'Pr�nom': 'Michel', 'Nom': 'Castellani', 'R�gion': 'Corse', 'D�partement': 'Haute-Corse', 'Num�ro de circonscription': '1', 'Profession': 'Professeur des Universit�s', 'Groupe politique (complet)': 'Libert�s et Territoires', 'Parti': 'LT'}
# {'identifiant': '720334', 'Pr�nom': 'Jimmy', 'Nom': 'Pahun', 'R�gion': 'Bretagne', 'D�partement': 'Morbihan', 'Num�ro de circonscription': '2', 'Profession': 'Navigateur', 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '2529', 'Pr�nom': 'Jean-Luc', 'Nom': 'Reitzer', 'R�gion': 'Grand Est', 'D�partement': 'Haut-Rhin', 'Num�ro de circonscription': '3', 'Profession': "Cadre d'entreprise charg� des relations sociales", 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '718926', 'Pr�nom': 'Pierre', 'Nom': 'Dharr�ville', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Bouches-du-Rh�ne', 'Num�ro de circonscription': '13', 'Profession': 'Employ� (secteur priv�)', 'Groupe politique (complet)': 'Gauche d�mocrate et r�publicaine', 'Parti': 'GDR'}
# {'identifiant': '720222', 'Pr�nom': '�ric', 'Nom': 'Girardin', 'R�gion': 'Grand Est', 'D�partement': 'Marne', 'Num�ro de circonscription': '3', 'Profession': "Industriel-Chef d'entreprise", 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '695100', 'Pr�nom': 'Meyer', 'Nom': 'Habib', 'R�gion': 'Fran�ais �tablis hors de France', 'D�partement': 'Fran�ais �tablis hors de France', 'Num�ro de circonscription': '8', 'Profession': 'Ing�nieur', 'Groupe politique (complet)': 'UDI et Ind�pendants', 'Parti': 'UDI-I'}
# {'identifiant': '677483', 'Pr�nom': 'St�phane', 'Nom': 'Mazars', 'R�gion': 'Occitanie', 'D�partement': 'Aveyron', 'Num�ro de circonscription': '1', 'Profession': 'Avocat', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '722374', 'Pr�nom': 'Cyrille', 'Nom': 'Isaac-Sibille', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Rh�ne', 'Num�ro de circonscription': '12', 'Profession': 'M�decin', 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '721996', 'Pr�nom': 'Patrick', 'Nom': 'Loiseau', 'R�gion': 'Pays de la Loire', 'D�partement': 'Vend�e', 'Num�ro de circonscription': '2', 'Profession': 'Cadre sup�rieur de la fonction publique territoriale', 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '643134', 'Pr�nom': 'Isabelle', 'Nom': 'Valentin', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Haute-Loire', 'Num�ro de circonscription': '1', 'Profession': 'Salari�e agricole', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '340343', 'Pr�nom': 'Herv�', 'Nom': 'Saulignac', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Ard�che', 'Num�ro de circonscription': '1', 'Profession': 'Cadre (entreprises publiques)', 'Groupe politique (complet)': 'Socialistes et apparent�s', 'Parti': 'SOC'}
# {'identifiant': '722390', 'Pr�nom': 'Josiane', 'Nom': 'Corneloup', 'R�gion': 'Bourgogne-Franche-Comt�', 'D�partement': 'Sa�ne-et-Loire', 'Num�ro de circonscription': '2', 'Profession': 'Pharmacienne', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '720968', 'Pr�nom': 'Justine', 'Nom': 'Benin', 'R�gion': 'Guadeloupe', 'D�partement': 'Guadeloupe', 'Num�ro de circonscription': '2', 'Profession': 'Fonctionnaire de cat�gorie B', 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '643145', 'Pr�nom': 'H�l�ne', 'Nom': 'Vainqueur-Christophe', 'R�gion': 'Guadeloupe', 'D�partement': 'Guadeloupe', 'Num�ro de circonscription': '4', 'Profession': 'Pharmacienne', 'Groupe politique (complet)': 'Socialistes et apparent�s', 'Parti': 'SOC'}
# {'identifiant': '719882', 'Pr�nom': 'Marjolaine', 'Nom': 'Meynier-Millefert', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Is�re', 'Num�ro de circonscription': '10', 'Profession': 'Consultante', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '332523', 'Pr�nom': 'Marie-Christine', 'Nom': 'Dalloz', 'R�gion': 'Bourgogne-Franche-Comt�', 'D�partement': 'Jura', 'Num�ro de circonscription': '2', 'Profession': 'Autre profession', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '721768', 'Pr�nom': 'Marie', 'Nom': 'Silin', 'R�gion': 'Ile-de-France', 'D�partement': 'Paris', 'Num�ro de circonscription': '12', 'Profession': 'Cadre en entreprise', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719632', 'Pr�nom': 'Sophie', 'Nom': 'Panonacle', 'R�gion': 'Nouvelle-Aquitaine', 'D�partement': 'Gironde', 'Num�ro de circonscription': '8', 'Profession': 'Sans profession d�clar�e', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720846', 'Pr�nom': 'Bastien', 'Nom': 'Lachaud', 'R�gion': 'Ile-de-France', 'D�partement': 'Seine-Saint-Denis', 'Num�ro de circonscription': '6', 'Profession': 'Professeur du secondaire et technique', 'Groupe politique (complet)': 'La France insoumise', 'Parti': 'FI'}
# {'identifiant': '722022', 'Pr�nom': 'La�titia', 'Nom': 'Romeiro Dias', 'R�gion': 'Ile-de-France', 'D�partement': 'Essonne', 'Num�ro de circonscription': '3', 'Profession': 'Juriste', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '606507', 'Pr�nom': 'Florent', 'Nom': 'Boudi�', 'R�gion': 'Nouvelle-Aquitaine', 'D�partement': 'Gironde', 'Num�ro de circonscription': '10', 'Profession': 'Cadre sup�rieur du secteur public', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720622', 'Pr�nom': 'Carole', 'Nom': 'Bureau-Bonnard', 'R�gion': 'Hauts-de-France', 'D�partement': 'Oise', 'Num�ro de circonscription': '6', 'Profession': 'Masseur-kin�sith�rapeute', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719520', 'Pr�nom': 'Micka�l', 'Nom': 'Nogal', 'R�gion': 'Occitanie', 'D�partement': 'Haute-Garonne', 'Num�ro de circonscription': '4', 'Profession': 'Autre profession lib�rale', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719258', 'Pr�nom': 'Michel', 'Nom': 'Delpon', 'R�gion': 'Nouvelle-Aquitaine', 'D�partement': 'Dordogne', 'Num�ro de circonscription': '2', 'Profession': 'Retrait� salari� du priv�', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '267378', 'Pr�nom': 'Genevi�ve', 'Nom': 'Levy', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Var', 'Num�ro de circonscription': '1', 'Profession': 'Expert foncier et commercial', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '719272', 'Pr�nom': 'Fr�d�rique', 'Nom': 'Meunier', 'R�gion': 'Nouvelle-Aquitaine', 'D�partement': 'Corr�ze', 'Num�ro de circonscription': '2', 'Profession': 'Avocate', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '719146', 'Pr�nom': 'Jean-F�lix', 'Nom': 'Acquaviva', 'R�gion': 'Corse', 'D�partement': 'Haute-Corse', 'Num�ro de circonscription': '2', 'Profession': 'Cadre', 'Groupe politique (complet)': 'Libert�s et Territoires', 'Parti': 'LT'}
# {'identifiant': '720342', 'Pr�nom': 'Nicole', 'Nom': 'Le Peih', 'R�gion': 'Bretagne', 'D�partement': 'Morbihan', 'Num�ro de circonscription': '3', 'Profession': 'Agriculteur-propri�taire exploitant', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '719162', 'Pr�nom': 'Jacqueline', 'Nom': 'Dubois', 'R�gion': 'Nouvelle-Aquitaine', 'D�partement': 'Dordogne', 'Num�ro de circonscription': '4', 'Profession': "Retrait�e de l'enseignement", 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '721314', 'Pr�nom': 'Rapha�l', 'Nom': 'Schellenberger', 'R�gion': 'Grand Est', 'D�partement': 'Haut-Rhin', 'Num�ro de circonscription': '4', 'Profession': 'Attach� Parlementaire', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '718930', 'Pr�nom': 'Anne-Laurence', 'Nom': 'Petel', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Bouches-du-Rh�ne', 'Num�ro de circonscription': '14', 'Profession': 'Charg�e des relations ext�rieures - secteur t�l�com', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '721328', 'Pr�nom': 'Anne', 'Nom': 'Brugnera', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Rh�ne', 'Num�ro de circonscription': '4', 'Profession': 'Fonctionnaire de cat�gorie A', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '721632', 'Pr�nom': 'Patricia', 'Nom': 'Lemoine', 'R�gion': 'Ile-de-France', 'D�partement': 'Seine-et-Marne', 'Num�ro de circonscription': '5', 'Profession': 'agent immobilier', 'Groupe politique (complet)': 'Agir ensemble', 'Parti': 'Agir ens'}
# {'identifiant': '720230', 'Pr�nom': 'Lise', 'Nom': 'Magnier', 'R�gion': 'Grand Est', 'D�partement': 'Marne', 'Num�ro de circonscription': '4', 'Profession': 'cadre territorial', 'Groupe politique (complet)': 'Agir ensemble', 'Parti': 'Agir ens'}
# {'identifiant': '267794', 'Pr�nom': 'Mich�le', 'Nom': 'Tabarot', 'R�gion': "Provence-Alpes-C�te d'Azur", 'D�partement': 'Alpes-Maritimes', 'Num�ro de circonscription': '9', 'Profession': "Chef d'entreprise", 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '722382', 'Pr�nom': 'Benjamin', 'Nom': 'Dirx', 'R�gion': 'Bourgogne-Franche-Comt�', 'D�partement': 'Sa�ne-et-Loire', 'Num�ro de circonscription': '1', 'Profession': "Industriel-Chef d'entreprise", 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '342415', 'Pr�nom': 'Marie-No�lle', 'Nom': 'Battistel', 'R�gion': 'Auvergne-Rh�ne-Alpes', 'D�partement': 'Is�re', 'Num�ro de circonscription': '4', 'Profession': 'Autre cadre (secteur priv�)', 'Groupe politique (complet)': 'Socialistes et apparent�s', 'Parti': 'SOC'}
# {'identifiant': '722398', 'Pr�nom': 'R�my', 'Nom': 'Rebeyrotte', 'R�gion': 'Bourgogne-Franche-Comt�', 'D�partement': 'Sa�ne-et-Loire', 'Num�ro de circonscription': '3', 'Profession': "Professeur d'�conomie", 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '720976', 'Pr�nom': 'Max', 'Nom': 'Mathiasin', 'R�gion': 'Guadeloupe', 'D�partement': 'Guadeloupe', 'Num�ro de circonscription': '3', 'Profession': 'Fonction publique territoriale', 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '720988', 'Pr�nom': 'Josette', 'Nom': 'Manin', 'R�gion': 'Martinique', 'D�partement': 'Martinique', 'Num�ro de circonscription': '1', 'Profession': 'Retrait�e salari�e (secteur priv�)', 'Groupe politique (complet)': 'Socialistes et apparent�s', 'Parti': 'SOC'}
# {'identifiant': '721760', 'Pr�nom': 'Maud', 'Nom': 'Gatel', 'R�gion': 'Ile-de-France', 'D�partement': 'Paris', 'Num�ro de circonscription': '11', 'Profession': "Directrice g�n�rale adjointe d'une agence de communication", 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '267204', 'Pr�nom': 'Jean-Marie', 'Nom': 'Sermier', 'R�gion': 'Bourgogne-Franche-Comt�', 'D�partement': 'Jura', 'Num�ro de circonscription': '3', 'Profession': 'Ancien viticulteur', 'Groupe politique (complet)': 'Les R�publicains', 'Parti': 'LR'}
# {'identifiant': '719640', 'Pr�nom': 'Sophie', 'Nom': 'Mette', 'R�gion': 'Nouvelle-Aquitaine', 'D�partement': 'Gironde', 'Num�ro de circonscription': '9', 'Profession': 'Sans profession d�clar�e', 'Groupe politique (complet)': 'Mouvement D�mocrate (MoDem) et D�mocrates apparent�s', 'Parti': 'Dem'}
# {'identifiant': '720854', 'Pr�nom': 'St�phane', 'Nom': 'Test�', 'R�gion': 'Ile-de-France', 'D�partement': 'Seine-Saint-Denis', 'Num�ro de circonscription': '12', 'Profession': "Enseignant du 1er d�gr�-Directeur d'�cole", 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}
# {'identifiant': '722030', 'Pr�nom': 'Pierre-Yves', 'Nom': 'Bournazel', 'R�gion': 'Ile-de-France', 'D�partement': 'Paris', 'Num�ro de circonscription': '18', 'Profession': 'Ancien auto-entrepreneur', 'Groupe politique (complet)': 'Agir ensemble', 'Parti': 'Agir ens'}
# {'identifiant': '719652', 'Pr�nom': 'V�ronique', 'Nom': 'Hammerer', 'R�gion': 'Nouvelle-Aquitaine', 'D�partement': 'Gironde', 'Num�ro de circonscription': '11', 'Profession': 'Fonctionnaire de cat�gorie A', 'Groupe politique (complet)': 'La R�publique en Marche', 'Parti': 'LaREM'}

# %% [markdown]
# On affichera alors tous les partis politiques avec :

# %%
with open('dataset/liste_deputes_excel.csv') as fichiercsv:
    reader = csv.DictReader(fichiercsv)
    for ligne in reader:
        print(ligne['Parti'], end=' ')
# Out:
# LR LaREM LaREM LaREM LR LaREM LT LaREM LaREM Agir ens FI Dem LR LaREM LaREM LR SOC LaREM LR Agir ens LR LaREM LR LaREM LaREM LR LaREM LaREM LaREM LT LR LaREM LaREM LaREM LaREM LaREM LaREM LaREM LaREM LR LaREM LaREM UDI-I LaREM LR SOC LaREM LaREM LaREM LaREM Dem LR LaREM LaREM NI LaREM LR LaREM Dem LaREM LaREM SOC LaREM LR LR LaREM FI Dem GDR LR FI LaREM LaREM Dem LaREM LR LT LaREM LaREM LaREM LaREM LaREM LaREM LR LaREM Dem LaREM LaREM FI LaREM LaREM GDR UDI-I SOC Agir ens LaREM LaREM LaREM LR LaREM LaREM LaREM LaREM LR LR Dem LaREM LT SOC LR LaREM LaREM LR Agir ens SOC LaREM LaREM GDR LaREM LaREM LaREM LaREM NI LaREM LR Dem LaREM LR LR LaREM LR LaREM LR SOC GDR LaREM LR LaREM GDR UDI-I LaREM LaREM LaREM Dem LR SOC FI LaREM LaREM LaREM LaREM LR LaREM LR SOC LR LR LR LaREM LaREM LaREM LaREM NI Dem Dem LaREM LR LaREM LaREM LaREM LaREM LR LaREM FI LR SOC LaREM SOC LR SOC LR NI LaREM LaREM SOC LR Dem LaREM LaREM LR LaREM LaREM Dem LaREM LR LaREM LaREM LR GDR LR FI LaREM LaREM NI LaREM FI LaREM GDR LaREM LaREM LaREM LaREM UDI-I Dem Dem LaREM LT Dem LaREM LaREM LaREM LaREM NI UDI-I LaREM UDI-I GDR Dem Dem GDR SOC SOC Dem LaREM LaREM Agir ens LR Agir ens NI LaREM LaREM Dem LT LaREM FI LaREM LR Agir ens UDI-I LT LaREM LaREM Dem LaREM LaREM LaREM UDI-I LaREM LaREM LaREM UDI-I LR LR Agir ens LaREM FI NI LaREM UDI-I GDR Agir ens LaREM LaREM LaREM LaREM LaREM LR LaREM Dem Dem LaREM LaREM LaREM LaREM LaREM LaREM LaREM Dem LR LaREM LR LaREM Dem LaREM LaREM LaREM Dem NI UDI-I NI LaREM LaREM LaREM LaREM LaREM Dem Dem LaREM LaREM UDI-I LR LaREM Agir ens LR SOC LaREM LaREM UDI-I FI LR LaREM GDR LR LaREM LaREM LaREM LT LR Dem LaREM Dem LaREM LaREM LaREM LR LR LR LR Agir ens Dem Dem LR LaREM LaREM UDI-I NI LaREM LaREM LaREM SOC LaREM SOC LR LaREM LR LR FI LaREM SOC Dem LR LaREM LaREM UDI-I LaREM LaREM LR SOC LR SOC UDI-I LR Dem LaREM GDR Dem LR LaREM LaREM LR LR LaREM LaREM Agir ens LaREM LT LR FI FI LaREM Dem Agir ens LT SOC LR LaREM LaREM LaREM Agir ens LT NI LaREM LaREM LT LaREM LaREM Dem LR NI NI LR LaREM SOC LaREM LaREM LaREM LaREM LR SOC NI LaREM LR Dem LaREM Agir ens LaREM LaREM LT Dem LaREM NI LT FI LR LaREM NI LR LaREM LaREM LaREM LaREM LR NI LaREM LaREM LR LaREM LaREM LaREM Dem LT LaREM LaREM NI LR Dem LaREM LaREM LaREM GDR LT LR LaREM LR FI LaREM LR LR LaREM LaREM NI LaREM Agir ens LaREM Dem NI LaREM LaREM NI UDI-I Dem LaREM Agir ens GDR Dem Dem LaREM LaREM LaREM LaREM LaREM LaREM Dem LaREM LR Agir ens Agir ens LR Dem LaREM LaREM LaREM LaREM Dem LaREM LaREM LR Dem LaREM LaREM UDI-I LaREM NI LR LR LaREM LaREM LaREM LaREM Dem LaREM LaREM LT Dem LR GDR LaREM UDI-I LaREM Dem Dem LR SOC LR Dem SOC LaREM LR LaREM LaREM FI LaREM LaREM LaREM LaREM LaREM LR LR LT LaREM LaREM LR LaREM LaREM Agir ens Agir ens LR LaREM SOC LaREM Dem SOC Dem LR Dem LaREM Agir ens LaREM

# %% [markdown]
# 1) À l'aide de la structure `set` en python, donnez la liste des partis politiques présents dans le fichier. On utilisera la fonction `list()` et la liste sera nommée `liste_partis`

# %%
# Out:
# ['Dem', 'LaREM', 'NI', 'GDR', 'LR', 'SOC', 'FI', 'UDI-I', 'Agir ens', 'LT']

# %% [markdown]
# 2) Nous allons compter le nombre de députés par partis
# * la structure de données dictionnaire semble la plus adaptée. Nous initialisons un dictionnaire et pouvons accéder à la valeur associée à une clé de la façon suivante :

# %%
dico_partis = {parti:0 for parti in liste_partis}
dico_partis['LaREM']
# Out:
# 0

# %% [markdown]
# *  Ensuite comptez les députés par partis :

# %%
# Out:
# {'Dem': 57,
#  'LaREM': 268,
#  'NI': 23,
#  'GDR': 15,
#  'LR': 101,
#  'SOC': 28,
#  'FI': 17,
#  'UDI-I': 19,
#  'Agir ens': 22,
#  'LT': 18}

# %% [markdown]
# 3) Représenter sous forme de diagramme circulaire la répartition des députés à l'Assemble Nationale !
